# %%
# imagined speech, fig 3a, 1 prediction similarity to stimulus vs 1 prediction similaairity to incorrect stimulus, pairwise accuracy, can only classify, not significant

# no data yet for incorrect transcript's similarity

import numpy as np
import pandas as pd

scores = np.load('scores_bravo_ref_ims/S2/imagined_speech/bravo_repeat-1.npz', allow_pickle=True)
print(scores.files)
score_names = ['window_scores', 'window_zscores', 'story_scores', 'story_zscores']
score_files = {}
for name in score_names:
    score_files[name] = scores[name].item()

print(score_files['story_zscores'])
print(score_files['story_zscores'][('bravo', 'BERT')])
# Out:
# ['window_scores', 'window_zscores', 'story_scores', 'story_zscores']
# {('bravo', 'WER'): np.float64(-0.9997299691880507), ('bravo', 'BLEU'): np.float64(0.2935050854653309), ('bravo', 'METEOR'): np.float64(0.8340520762293799), ('bravo', 'BERT'): np.float32(3.4985328)}
# 3.4985328

# %%
zscores_df = pd.DataFrame({'task':[], 'alpha_ref':[],'bravo_ref':[],'charlie_ref':[], 'delta_ref':[], 'echo_ref':[]})

to_add = {'task':[], 'alpha_ref':[],'bravo_ref':[],'charlie_ref':[], 'delta_ref':[], 'echo_ref':[]}
for task in ['alpha','bravo', 'charlie', 'delta', 'echo']:
    for repeat in [1,2]:
        to_add['task'].append(f'{task}_repeat-{repeat}')
        for ref in ['alpha','bravo', 'charlie', 'delta', 'echo']:
            scores = np.load(f'scores_{ref}_ref_ims/S2/imagined_speech/{task}_repeat-{repeat}.npz', allow_pickle=True)
            # print(scores['story_zscores'].item()[(ref, 'BLEU')])
            to_add[f'{ref}_ref'].append(scores['story_zscores'].item()[(ref, 'BERT')])

zscores_df = pd.DataFrame(to_add)

zscores_df
# Out:
#                task  alpha_ref  bravo_ref  charlie_ref  delta_ref  echo_ref
# 0    alpha_repeat-1   0.794526   0.803212     0.782517   0.797073  0.783702
# 1    alpha_repeat-2   0.808962   0.807357     0.786780   0.799933  0.784936
# 2    bravo_repeat-1   0.799152   0.816933     0.789133   0.802897  0.783768
# 3    bravo_repeat-2   0.800113   0.816908     0.788535   0.805473  0.781310
# 4  charlie_repeat-1   0.798068   0.811161     0.804764   0.811174  0.786584
# 5  charlie_repeat-2   0.797936   0.811381     0.806555   0.810030  0.784825
# 6    delta_repeat-1   0.795062   0.809244     0.785830   0.815349  0.788073
# 7    delta_repeat-2   0.795918   0.806841     0.792155   0.821874  0.784981
# 8     echo_repeat-1   0.796131   0.802391     0.785681   0.806262  0.785919
# 9     echo_repeat-2   0.798817   0.806742     0.790438   0.806100  0.794162

# %%
zscores_df.to_csv('imagined_speech_zscores.csv', index=False)

zscores_df
# Out:
#                task  alpha_ref  bravo_ref  charlie_ref  delta_ref  echo_ref
# 0    alpha_repeat-1   0.794526   0.803212     0.782517   0.797073  0.783702
# 1    alpha_repeat-2   0.808962   0.807357     0.786780   0.799933  0.784936
# 2    bravo_repeat-1   0.799152   0.816933     0.789133   0.802897  0.783768
# 3    bravo_repeat-2   0.800113   0.816908     0.788535   0.805473  0.781310
# 4  charlie_repeat-1   0.798068   0.811161     0.804764   0.811174  0.786584
# 5  charlie_repeat-2   0.797936   0.811381     0.806555   0.810030  0.784825
# 6    delta_repeat-1   0.795062   0.809244     0.785830   0.815349  0.788073
# 7    delta_repeat-2   0.795918   0.806841     0.792155   0.821874  0.784981
# 8     echo_repeat-1   0.796131   0.802391     0.785681   0.806262  0.785919
# 9     echo_repeat-2   0.798817   0.806742     0.790438   0.806100  0.794162

# %%
results = np.load('results/S2/perceived_speech/wheretheressmoke.npz', allow_pickle=True)
result_names = results.files
result_files={}
for name in result_names:
    result_files[name] = results[name]
result_files
# Out:
# {'words': array(['i', "don't", 'have', ..., 'world', 'i', 'could'],
#        shape=(1588,), dtype='<U12'),
#  'times': array([ 10.2,  10.6,  11. , ..., 591. , 591.4, 591.8], shape=(1588,))}
