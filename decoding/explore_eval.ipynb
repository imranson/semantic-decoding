# %%
import numpy as np
import pandas as pd

results = np.load('../scores/S1/imagined_speech/alpha_repeat-1.npz', allow_pickle=True)
print(results.files)

print(results['window_scores'])
# Out:
# ['window_scores', 'window_zscores', 'story_scores', 'story_zscores']
# {('alpha_repeat-1', 'WER'): array([-0.01886792, -0.07843137, -0.125     , -0.1       , -0.10204082,
#        -0.125     , -0.10416667, -0.06122449, -0.12765957, -0.03921569,
#        -0.03921569, -0.06      , -0.12765957, -0.08163265, -0.17777778,
#        -0.24390244, -0.38888889, -0.48484848, -0.45454545, -0.44117647,
#        -0.47058824, -0.44117647, -0.38888889, -0.36111111, -0.41176471,
#        -0.28947368, -0.2972973 , -0.36111111, -0.23076923, -0.20512821,
#        -0.25641026, -0.25      , -0.21428571, -0.225     , -0.13953488,
#        -0.06382979, -0.04081633, -0.04      , -0.06      , -0.06      ,
#        -0.04      ]), ('alpha_repeat-1', 'BLEU'): array([0.20689655, 0.20689655, 0.20689655, 0.23728814, 0.23728814,
#        0.24137931, 0.24137931, 0.25862069, 0.25862069, 0.27586207,
#        0.31034483, 0.29310345, 0.31034483, 0.32758621, 0.32758621,
# ...

# %%
results.files
# Out:
# ['window_scores', 'window_zscores', 'story_scores', 'story_zscores']
